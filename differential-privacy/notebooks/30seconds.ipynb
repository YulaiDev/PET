# %% [markdown]
#     # Getting started: Machine learning with differential privacy in 30 seconds

# %% [markdown]
# We're using the [Iris dataset](https://archive.ics.uci.edu/ml/datasets/iris), so let's load it and perform an 80/20 train/test split.

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split

dataset = datasets.load_iris()
X_train, X_test, y_train, y_test = train_test_split(dataset.data, dataset.target, test_size=0.2)

# %% [markdown]
# Now, let's train a differentially private naive Bayes classifier. Our classifier __runs just like an `sklearn` classifier__, so you can get up and running quickly.
#
# `diffprivlib.models.GaussianNB` can be run __without any parameters__, although this will throw a warning (we need to specify the `bounds` parameter to avoid this). The privacy level is controlled by the parameter `epsilon`, which is passed to the classifier at initialisation (e.g. `GaussianNB(epsilon=0.1)`). The default is `epsilon = 1.0`.

# %%
from diffprivlib.models import GaussianNB

clf = GaussianNB()
clf.fit(X_train, y_train)
# Out:
# /Users/najahkhalifa/venv/lib/python3.9/site-packages/diffprivlib/models/naive_bayes.py:107: PrivacyLeakWarning: Bounds have not been specified and will be calculated on the data provided. This will result in additional privacy leakage. To ensure differential privacy and no additional privacy leakage, specify bounds for each dimension.
#   warnings.warn("Bounds have not been specified and will be calculated on the data provided. This will "
# GaussianNB(accountant=BudgetAccountant(spent_budget=[(1.0, 0), (0.01, 0), (0.012067926406393288, 0), (0.014563484775012436, 0), (0.017575106248547922, 0), ...]),
#            bounds=(array([4.3, 2. , 1. , 0.1]), array([7.7, 4.4, 6.9, 2.5])))

# %% [markdown]
# We can now classify unseen examples, knowing that the trained model is differentially private and preserves the privacy of the 'individuals' in the training set (flowers are entitled to their privacy too!).

# %%
clf.predict(X_test)
# Out:
# array([2, 0, 2, 0, 0, 0, 2, 2, 0, 1, 0, 0, 0, 0, 0, 1, 0, 1, 0, 2, 0, 0,
#        2, 0, 2, 0, 0, 0, 1, 0])

# %% [markdown]
# Every time the model is trained with `.fit()`, a different model is produced due to the randomness of differential privacy. The accuracy will therefore change, even if it's re-trained with the same training data. Try it for yourself to find out!

# %%
print("Test accuracy: %f" % clf.score(X_test, y_test))
# Out:
# Test accuracy: 0.633333

# %% [markdown]
# We can easily evaluate the accuracy of the model for various `epsilon` values and plot it with `matplotlib`.

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Users/najahkhalifa/venv/lib/python3.9/site-packages (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/najahkhalifa/venv/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/najahkhalifa/venv/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/najahkhalifa/venv/lib/python3.9/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/najahkhalifa/venv/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /Users/najahkhalifa/venv/lib/python3.9/site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /Users/najahkhalifa/venv/lib/python3.9/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/najahkhalifa/venv/lib/python3.9/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/najahkhalifa/venv/lib/python3.9/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/najahkhalifa/venv/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/najahkhalifa/venv/lib/python3.9/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/najahkhalifa/venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in /Users/najahkhalifa/venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import numpy as np
import matplotlib.pyplot as plt

epsilons = np.logspace(-2, 2, 50)
bounds = ([4.3, 2.0, 1.1, 0.1], [7.9, 4.4, 6.9, 2.5])
accuracy = list()
#In plaats van zomaar willekeurige waarden te gebruiken, is gekozen voor np.logspace(-2, 2, 50). wat doet de logspace 
#Dit zorgt voor een goede verdeling tussen lage en hoge privacywaarden.
for epsilon in epsilons:
    clf = GaussianNB(bounds=bounds, epsilon=epsilon)
    clf.fit(X_train, y_train)
    
    accuracy.append(clf.score(X_test, y_test))

plt.semilogx(epsilons, accuracy)
plt.title("Differentially private Naive Bayes accuracy")
plt.xlabel("epsilon")
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# Congratulations, you've completed your first differentially private machine learning task with the Differential Privacy Library!  Check out more examples in the [notebooks](./) directory, or [dive straight in](../diffprivlib/).
